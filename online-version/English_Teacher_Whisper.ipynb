# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandro-campos-dev/english-teacher-with-whisher/blob/main/online-version/English_Teacher_Whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎓 English Teacher Assistant (Colab Version)
#
# ✅ Refactored structure
# ✅ Logical modular sections (as notebook modules)
# ✅ Secure OpenAI API Key via **Colab Secrets**
#
# ---
# This notebook is fully compatible with **Google Colab**.

# %% [markdown]
# ## 1️⃣ Install Dependencies

# %%
# !pip install -q openai==1.6.1 httpx==0.27.0 openai-whisper gTTS pydub pygame

# %% [markdown]
# ## 2️⃣ Load OpenAI API Key from Colab Secrets
#
# 🔐 Go to **Colab → Secrets → Add new secret**
# - Name: `OPENAI_API_KEY`
# - Value: your API key

# %%
from google.colab import userdata
import os

os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
assert os.environ['OPENAI_API_KEY'], '❌ API Key not found in Colab Secrets'
print('✅ OpenAI API Key loaded securely')
# Out:
# ✅ OpenAI API Key loaded securely

# %% [markdown]
# ## 3️⃣ OpenAI Client (v1.x API)

# %%
from openai import OpenAI
import os
from google.colab import userdata # Import userdata

# A API Key deve estar no Colab Secrets como OPENAI_API_KEY
# Ensure the API key is loaded from Colab secrets if not already in env
if not os.getenv("OPENAI_API_KEY"):
    os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def chatgpt_teacher(prompt):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a friendly English teacher."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=150,
        temperature=0.7
    )
    return response.choices[0].message.content

print("✅ OpenAI client ready")
# Out:
# ✅ OpenAI client ready

# %% [markdown]
# ## 4️⃣ Whisper Speech-to-Text Module

# %%
import whisper

model = whisper.load_model('base')

def transcribe_audio(path):
    result = model.transcribe(path, language='en', fp16=False)
    return result['text']

print('✅ Whisper loaded')
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:13<00:00, 11.1MiB/s]
# ✅ Whisper loaded

# %% [markdown]
# ## 5️⃣ Text-to-Speech Module

# %%
from gtts import gTTS
from IPython.display import Audio, display
import tempfile

def speak(text):
    tts = gTTS(text=text, lang='en')
    with tempfile.NamedTemporaryFile(delete=False, suffix='.mp3') as f:
        tts.save(f.name)
        display(Audio(f.name, autoplay=True))

print('✅ Text-to-Speech ready')
# Out:
# ✅ Text-to-Speech ready

# %% [markdown]
# ## 6️⃣ English Placement Test (Quota-safe)
#
# ⚠️ Uses **short prompt** to avoid RateLimit / quota issues.

# %%
level_prompt = 'Classify the English level (Beginner, Intermediate, Advanced):\nI like learn English because job.'

student_level = chatgpt_teacher(level_prompt)
print('Detected level:', student_level)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-146651720.py in <cell line: 0>()
#       1 level_prompt = 'Classify the English level (Beginner, Intermediate, Advanced):\nI like learn English because job.'
#       2
# ----> 3 student_level = chatgpt_teacher(level_prompt)
#       4 print('Detected level:', student_level)
#
# /tmp/ipython-input-3448814927.py in chatgpt_teacher(prompt)
#      11
#      12 def chatgpt_teacher(prompt):
# ---> 13     response = client.chat.completions.create(
#      14         model="gpt-3.5-turbo",
#      15         messages=[
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     270                         msg = f"Missing required argument: {quote(missing[0])}"
#     271                 raise TypeError(msg)
# --> 272             return func(*args, **kwargs)
#     273
#     274         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     643         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     644     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 645         return self._post(
#     646             "/chat/completions",
#     647             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1086             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1087         )
# -> 1088         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1089
#    1090     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     851         stream_cls: type[_StreamT] | None = None,
#     852     ) -> ResponseT | _StreamT:
# --> 853         return self._request(
#     854             cast_to=cast_to,
#     855             options=options,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914             if retries > 0 and self._should_retry(err.response):
#     915                 err.response.close()
# --> 916                 return self._retry_request(
#     917                     options,
#     918                     cast_to,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     914             if retries > 0 and self._should_retry(err.response):
#     915                 err.response.close()
# --> 916                 return self._retry_request(
#     917                     options,
#     918                     cast_to,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     956         time.sleep(timeout)
#     957
# --> 958         return self._request(
#     959             options=options,
#     960             cast_to=cast_to,
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928                 err.response.read()
#     929
# --> 930             raise self._make_status_error_from_response(err.response) from None
#     931
#     932         return self._process_response(
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %% [markdown]
# ## 7️⃣ Interactive Practice

# %%
while True:
    user_input = input('\nYou (type quit to stop): ')
    if user_input.lower() == 'quit':
        break
    reply = chatgpt_teacher(user_input)
    print('\nTeacher:', reply)
    speak(reply)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2937541240.py in <cell line: 0>()
#       1 while True:
# ----> 2     user_input = input('\nYou (type quit to stop): ')
#       3     if user_input.lower() == 'quit':
#       4         break
#       5     reply = chatgpt_teacher(user_input)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
